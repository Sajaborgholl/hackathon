# %%
import pandas as pd

file_path = 'relevant_features_dataset.csv'  # Path to the file
df_relevant = pd.read_csv(file_path)
# Print the first 5 rows
print("First 5 rows of the dataset:")
print(df_relevant.head())
# Out:
# First 5 rows of the dataset:
#   I_see_myself_as_someone_who_is_anxious_easily_upset  \
# 0                                   agree moderately
# 1                                     agree a little
# 2                                   agree moderately
# 3                                  disagree strongly
# 4                                disagree moderately
#
#   I_see_myself_as_someone_who_is_reserved_quiet Do_you_have_close_friends  \
# 0                                agree a little                       yes
# 1                             disagree strongly                       yes
# 2                              agree moderately                       yes
# 3                           disagree moderately                       yes
# 4                                agree strongly                       yes
#
#   I_see_myself_as_someone_who_is_calm_emotionally_stable Gender  \
# 0                                     agree a little       male
# 1                                     agree strongly       male
# 2                         neither agree nor disagree       male
# 3                         neither agree nor disagree       male
# 4                                     agree strongly       male
#
#   Do_you_find_it_difficult_to_refrain_from_smoking_where_it_is_forbidden_church_library_cinema_plane_etc  \
# 0                                                 no
# 1                                                 no
# 2                                                 no
# 3                                                 no
# 4                                                 no
#
#    How_old_were_you_the_first_time_you_smoked_a_full_cigarette_not_just_a_few_puffs  \
# 0                                                 17
# 1                                                 14
# 2                                                 17
# 3                                                 16
# 4                                                 18
#
#   What_is_your_favorite_or_preferred_cigarette_brands_if_you_were_able_to_access_it  \
# 0        marlboro or any other philip morris cigaret
# 1                                      marlboro gold
# 2                                             cedars
# 3                 parliament / cohiba / winston blue
# 4                                 winston red packet
#
#   What_is_the_highest_level_of_education_you_have_attained  \
# 0                            graduate degree (ma/ms)
# 1        high school degree or equivalent (e.g. ged)
# 2                            graduate degree (ma/ms)
# 3                       incomplete bachelor's degree
# 4                       incomplete bachelor's degree
#
#                   How_often_do_you_exercise  ...  \
# 0                                     never  ...
# 1       often or at least 3 days every week  ...
# 2  every day or at least 5 times every week  ...
# 3       often or at least 3 days every week  ...
# 4  every day or at least 5 times every week  ...
#
#    How_soon_after_you_wake_up_do_you_smoke_your_first_cigarette Last_page  \
# 0                                   31 to 60 minutes                    5
# 1                                   31 to 60 minutes                    5
# 2                                   after 60 minutes                    5
# 3                                    6 to 30 minutes                    5
# 4                                   after 60 minutes                    5
#
#   How_would_you_describe_your_current_smoking_behavior_compared_to_your_smoking_behavior_before_Lebanons_economic_crisis_and_revolution_began_in_2019  \
# 0  the number of cigarettes i smoke per day has r...
# 1  the number of cigarettes i smoke per day has d...
# 2  the number of cigarettes i smoke per day has r...
# 3  the number of cigarettes i smoke per day has r...
# 4  the number of cigarettes i smoke per day has r...
#
#   On_average_how_many_hours_per_day_do_you_spend_on_social_media_for_entertainment_and_social_interaction_Facebook_Instagram_YouTube_etc  \
# 0                              between 2 and 3 hours
# 1                              between 2 and 3 hours
# 2                                  more than 4 hours
# 3                              between 2 and 3 hours
# 4                                   less than 1 hour
#
#   Has_2019s_revolution_or_economic_crisis_caused_you_to_switch_away_from_your_favorite_or_preferred_cigarette_brands_to_an_alternative  \
# 0  no, i am currently using my favorite or prefer...
# 1    yes, i am currently using a cheaper alternative
# 2  no, i am currently using my favorite or prefer...
# 3    yes, i am currently using a cheaper alternative
# 4  no, i am currently using my favorite or prefer...
#
#    Have_you_smoked_at_least_one_full_tobacco_cigarette_excluding_ecigarettes_once_or_more_in_the_past_30_days  \
# 0                                                yes
# 1                                                yes
# 2                                                yes
# 3                                                yes
# 4                                                yes
#
#   What_type_of_income_or_financial_support_does_your_household_receive  \
# 0                             fully in lebanese lira
# 1                                fully in us dollars
# 2                             fully in lebanese lira
# 3                                              mixed
# 4                              other, please specify
#
#   Are_you_currently_able_to_afford_your_favorite_or_preferred_cigarette_brands  \
# 0                                                yes
# 1                                                 no
# 2                                                yes
# 3                                                yes
# 4                                                yes
#
#   Unnamed_0 How_often_do_you_feel_stressed
# 0         5                     frequently
# 1        11                   occasionally
# 2        14                     constantly
# 3        15                   occasionally
# 4        16                          never
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Step 1: Encode Categorical Variables
# - **Why**: Machine learning models require numeric inputs, so we convert categorical variables.
# - **What**:
#   - Use one-hot encoding for non-ordinal categorical features.
#   - This ensures each category is represented as a binary column.

# %%
# Step 1: Separate Target Column
target_column = "How_often_do_you_feel_stressed"
y = df_relevant[target_column]  # Extract the target variable
X = df_relevant.drop(columns=[target_column])
# Print the first 5 rows
print("First 5 rows of the dataset:")
print(df_relevant.head())
# Out:
# First 5 rows of the dataset:
#   I_see_myself_as_someone_who_is_anxious_easily_upset  \
# 0                                   agree moderately
# 1                                     agree a little
# 2                                   agree moderately
# 3                                  disagree strongly
# 4                                disagree moderately
#
#   I_see_myself_as_someone_who_is_reserved_quiet Do_you_have_close_friends  \
# 0                                agree a little                       yes
# 1                             disagree strongly                       yes
# 2                              agree moderately                       yes
# 3                           disagree moderately                       yes
# 4                                agree strongly                       yes
#
#   I_see_myself_as_someone_who_is_calm_emotionally_stable Gender  \
# 0                                     agree a little       male
# 1                                     agree strongly       male
# 2                         neither agree nor disagree       male
# 3                         neither agree nor disagree       male
# 4                                     agree strongly       male
#
#   Do_you_find_it_difficult_to_refrain_from_smoking_where_it_is_forbidden_church_library_cinema_plane_etc  \
# 0                                                 no
# 1                                                 no
# 2                                                 no
# 3                                                 no
# 4                                                 no
#
#    How_old_were_you_the_first_time_you_smoked_a_full_cigarette_not_just_a_few_puffs  \
# 0                                                 17
# 1                                                 14
# 2                                                 17
# 3                                                 16
# 4                                                 18
#
#   What_is_your_favorite_or_preferred_cigarette_brands_if_you_were_able_to_access_it  \
# 0        marlboro or any other philip morris cigaret
# 1                                      marlboro gold
# 2                                             cedars
# 3                 parliament / cohiba / winston blue
# 4                                 winston red packet
#
#   What_is_the_highest_level_of_education_you_have_attained  \
# 0                            graduate degree (ma/ms)
# 1        high school degree or equivalent (e.g. ged)
# 2                            graduate degree (ma/ms)
# 3                       incomplete bachelor's degree
# 4                       incomplete bachelor's degree
#
#                   How_often_do_you_exercise  ...  \
# 0                                     never  ...
# 1       often or at least 3 days every week  ...
# 2  every day or at least 5 times every week  ...
# 3       often or at least 3 days every week  ...
# 4  every day or at least 5 times every week  ...
#
#    How_soon_after_you_wake_up_do_you_smoke_your_first_cigarette Last_page  \
# 0                                   31 to 60 minutes                    5
# 1                                   31 to 60 minutes                    5
# 2                                   after 60 minutes                    5
# 3                                    6 to 30 minutes                    5
# 4                                   after 60 minutes                    5
#
#   How_would_you_describe_your_current_smoking_behavior_compared_to_your_smoking_behavior_before_Lebanons_economic_crisis_and_revolution_began_in_2019  \
# 0  the number of cigarettes i smoke per day has r...
# 1  the number of cigarettes i smoke per day has d...
# 2  the number of cigarettes i smoke per day has r...
# 3  the number of cigarettes i smoke per day has r...
# 4  the number of cigarettes i smoke per day has r...
#
#   On_average_how_many_hours_per_day_do_you_spend_on_social_media_for_entertainment_and_social_interaction_Facebook_Instagram_YouTube_etc  \
# 0                              between 2 and 3 hours
# 1                              between 2 and 3 hours
# 2                                  more than 4 hours
# 3                              between 2 and 3 hours
# 4                                   less than 1 hour
#
#   Has_2019s_revolution_or_economic_crisis_caused_you_to_switch_away_from_your_favorite_or_preferred_cigarette_brands_to_an_alternative  \
# 0  no, i am currently using my favorite or prefer...
# 1    yes, i am currently using a cheaper alternative
# 2  no, i am currently using my favorite or prefer...
# 3    yes, i am currently using a cheaper alternative
# 4  no, i am currently using my favorite or prefer...
#
#    Have_you_smoked_at_least_one_full_tobacco_cigarette_excluding_ecigarettes_once_or_more_in_the_past_30_days  \
# 0                                                yes
# 1                                                yes
# 2                                                yes
# 3                                                yes
# 4                                                yes
#
#   What_type_of_income_or_financial_support_does_your_household_receive  \
# 0                             fully in lebanese lira
# 1                                fully in us dollars
# 2                             fully in lebanese lira
# 3                                              mixed
# 4                              other, please specify
#
#   Are_you_currently_able_to_afford_your_favorite_or_preferred_cigarette_brands  \
# 0                                                yes
# 1                                                 no
# 2                                                yes
# 3                                                yes
# 4                                                yes
#
#   Unnamed_0 How_often_do_you_feel_stressed
# 0         5                     frequently
# 1        11                   occasionally
# 2        14                     constantly
# 3        15                   occasionally
# 4        16                          never
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Step 2: Scale Numerical Features
# - **Why**: Numerical features often have different ranges, which can bias models sensitive to magnitude (e.g., SVM, KNN).
# - **What**:
#   - Standardize numeric features to have a mean of 0 and a standard deviation of 1.

# %%
# Step 2: Encode Categorical Variables in Features Only
categorical_cols = X.select_dtypes(include=['object']).columns
X_encoded = pd.get_dummies(X, columns=categorical_cols, drop_first=True)
# Print the first 5 rows
print("First 5 rows of the dataset:")
print(df_relevant.head())
# Out:
# First 5 rows of the dataset:
#   I_see_myself_as_someone_who_is_anxious_easily_upset  \
# 0                                   agree moderately
# 1                                     agree a little
# 2                                   agree moderately
# 3                                  disagree strongly
# 4                                disagree moderately
#
#   I_see_myself_as_someone_who_is_reserved_quiet Do_you_have_close_friends  \
# 0                                agree a little                       yes
# 1                             disagree strongly                       yes
# 2                              agree moderately                       yes
# 3                           disagree moderately                       yes
# 4                                agree strongly                       yes
#
#   I_see_myself_as_someone_who_is_calm_emotionally_stable Gender  \
# 0                                     agree a little       male
# 1                                     agree strongly       male
# 2                         neither agree nor disagree       male
# 3                         neither agree nor disagree       male
# 4                                     agree strongly       male
#
#   Do_you_find_it_difficult_to_refrain_from_smoking_where_it_is_forbidden_church_library_cinema_plane_etc  \
# 0                                                 no
# 1                                                 no
# 2                                                 no
# 3                                                 no
# 4                                                 no
#
#    How_old_were_you_the_first_time_you_smoked_a_full_cigarette_not_just_a_few_puffs  \
# 0                                                 17
# 1                                                 14
# 2                                                 17
# 3                                                 16
# 4                                                 18
#
#   What_is_your_favorite_or_preferred_cigarette_brands_if_you_were_able_to_access_it  \
# 0        marlboro or any other philip morris cigaret
# 1                                      marlboro gold
# 2                                             cedars
# 3                 parliament / cohiba / winston blue
# 4                                 winston red packet
#
#   What_is_the_highest_level_of_education_you_have_attained  \
# 0                            graduate degree (ma/ms)
# 1        high school degree or equivalent (e.g. ged)
# 2                            graduate degree (ma/ms)
# 3                       incomplete bachelor's degree
# 4                       incomplete bachelor's degree
#
#                   How_often_do_you_exercise  ...  \
# 0                                     never  ...
# 1       often or at least 3 days every week  ...
# 2  every day or at least 5 times every week  ...
# 3       often or at least 3 days every week  ...
# 4  every day or at least 5 times every week  ...
#
#    How_soon_after_you_wake_up_do_you_smoke_your_first_cigarette Last_page  \
# 0                                   31 to 60 minutes                    5
# 1                                   31 to 60 minutes                    5
# 2                                   after 60 minutes                    5
# 3                                    6 to 30 minutes                    5
# 4                                   after 60 minutes                    5
#
#   How_would_you_describe_your_current_smoking_behavior_compared_to_your_smoking_behavior_before_Lebanons_economic_crisis_and_revolution_began_in_2019  \
# 0  the number of cigarettes i smoke per day has r...
# 1  the number of cigarettes i smoke per day has d...
# 2  the number of cigarettes i smoke per day has r...
# 3  the number of cigarettes i smoke per day has r...
# 4  the number of cigarettes i smoke per day has r...
#
#   On_average_how_many_hours_per_day_do_you_spend_on_social_media_for_entertainment_and_social_interaction_Facebook_Instagram_YouTube_etc  \
# 0                              between 2 and 3 hours
# 1                              between 2 and 3 hours
# 2                                  more than 4 hours
# 3                              between 2 and 3 hours
# 4                                   less than 1 hour
#
#   Has_2019s_revolution_or_economic_crisis_caused_you_to_switch_away_from_your_favorite_or_preferred_cigarette_brands_to_an_alternative  \
# 0  no, i am currently using my favorite or prefer...
# 1    yes, i am currently using a cheaper alternative
# 2  no, i am currently using my favorite or prefer...
# 3    yes, i am currently using a cheaper alternative
# 4  no, i am currently using my favorite or prefer...
#
#    Have_you_smoked_at_least_one_full_tobacco_cigarette_excluding_ecigarettes_once_or_more_in_the_past_30_days  \
# 0                                                yes
# 1                                                yes
# 2                                                yes
# 3                                                yes
# 4                                                yes
#
#   What_type_of_income_or_financial_support_does_your_household_receive  \
# 0                             fully in lebanese lira
# 1                                fully in us dollars
# 2                             fully in lebanese lira
# 3                                              mixed
# 4                              other, please specify
#
#   Are_you_currently_able_to_afford_your_favorite_or_preferred_cigarette_brands  \
# 0                                                yes
# 1                                                 no
# 2                                                yes
# 3                                                yes
# 4                                                yes
#
#   Unnamed_0 How_often_do_you_feel_stressed
# 0         5                     frequently
# 1        11                   occasionally
# 2        14                     constantly
# 3        15                   occasionally
# 4        16                          never
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Step 3: Define Features and Target
# - **Why**: Separate the data into:
#   - `X`: Features used to predict the target.
#   - `y`: Target variable (stress levels).
# - **What**:
#   - Drop the target column from features.

# %%
# Step 3: Scale numerical features
from sklearn.preprocessing import StandardScaler

# Identify numeric columns in the feature set
numeric_cols = X_encoded.select_dtypes(include=['int64', 'float64']).columns
scaler = StandardScaler()
X_encoded[numeric_cols] = scaler.fit_transform(X_encoded[numeric_cols])

# Print examples after scaling
print("Examples after scaling numerical features:")
print(X_encoded[numeric_cols].head())
# Out:
# Examples after scaling numerical features:
#    How_old_were_you_the_first_time_you_smoked_a_full_cigarette_not_just_a_few_puffs  \
# 0                                          -0.081654
# 1                                          -0.103493
# 2                                          -0.081654
# 3                                          -0.088934
# 4                                          -0.074375
#
#    How_old_are_you  \
# 0         1.907435
# 1        -0.891016
# 2         0.508209
# 3        -0.541210
# 4        -0.541210
#
#    Including_yourself_how_many_people_currently_live_in_your_household  \
# 0                                          -0.059534
# 1                                          -0.059534
# 2                                          -0.059534
# 3                                           0.541472
# 4                                           1.142478
#
#    Last_page  Unnamed_0
# 0        0.0  -2.046917
# 1        0.0  -2.008033
# 2        0.0  -1.988591
# 3        0.0  -1.982110
# 4        0.0  -1.975630

# %%
# Check the class distribution in the target variable
print("Class distribution in target variable:")
print(y.value_counts())
# Out:
# Class distribution in target variable:
# How_often_do_you_feel_stressed
# frequently      88
# occasionally    64
# constantly      31
# rarely          28
# never            1
# Name: count, dtype: int64

# %%
# Remove rows with the rare class "never"
rare_class = 'never'
X_encoded = X_encoded[y != rare_class]
y = y[y != rare_class]

# %%
# Save the preprocessed data (features and target) to separate files
X_encoded_file_path = 'preprocessed_features.csv'
y_file_path = 'preprocessed_target.csv'

# Save the features and target as CSV files
X_encoded.to_csv(X_encoded_file_path, index=False)
y.to_csv(y_file_path, index=False)
